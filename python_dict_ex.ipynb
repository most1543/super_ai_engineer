# %% [markdown]
# <a href="https://colab.research.google.com/github/most1543/super_ai_engineer/blob/main/python_dict_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# string = input()

# mydict = {}
# for v in string:
#   mydict[v] = mydict.get(v,0)+1

# print(mydict)

# %%
# students_name = input()

# scores = {
#     "Alice": 85,
#     "Bob": 92,
#     "Charlie": 78
# }

# print(scores.get(students_name, "ไม่มีนักเรียนคนนี้"))
# Out:
# A
# ไม่มีนักเรียนคนนี้

# %%
# data = [("Alice", "Math"), ("Bob", "Math"), ("Alice", "Science")]

# group = {}

# for name, subject in data:
#     group.setdefault(name, []).append(subject)

# print(group)
# Out:
# {'Alice': ['Math', 'Science'], 'Bob': ['Math']}

# %%
# keys = ["name", "age", "city"]
# values = ["John", 25, "Bangkok", "AA"]

# print(dict(zip(keys, values)))
# Out:
# {'name': 'John', 'age': 25, 'city': 'AA'}

# %%
# scores = {'Alice': 90, 'Bob': 92, 'Charlie': 78, 'David': 88}

# reverse = {}

# for name, score in scores.items():
#     reverse.setdefault(score, []).append(name)

# print(reverse)
# Out:
# {90: ['Alice'], 92: ['Bob'], 78: ['Charlie'], 88: ['David']}

# %%
# students = {
#   "Alice": 85,
#   "Bob": 92,
#   "Charlie": 78
# }

# students.setdefault("David", 88)
# students["Alice"] = 90

# print(students)

# students.pop("Charlie", None)
# print(students)

# for name, score in students.items():
#   print(f"{name}: {score}")
# Out:
# {'Alice': 90, 'Bob': 92, 'Charlie': 78, 'David': 88}
# {'Alice': 90, 'Bob': 92, 'David': 88}
# Alice: 90
# Bob: 92
# David: 88

# %%
# dict1 = {'Alice': 90, 'Bob': 92}
# dict2 = {'Charlie': 78, 'David': 88}

# dict1.update(dict2)

# print(dict1)
# Out:
# {'Alice': 90, 'Bob': 92, 'Charlie': 78, 'David': 88}

# %%
# string = "banana"

# count = {}
# for i in string:
#   count[i] = count.setdefault(i, 0) + 1

# print(count)
# Out:
# {'b': 1, 'a': 3, 'n': 2}

# %% [markdown]
# ให้เขียนโปรแกรมรับข้อความ (string) จากผู้ใช้ แล้วแสดงผลว่า
# มีตัวอักษรที่ “ไม่ซ้ำกัน” กี่ตัว (ไม่นับช่องว่าง และไม่สนตัวพิมพ์เล็ก/ใหญ่)
#
# 🔹 ตัวอย่าง
# Input: Hello World
# Output: 7
#
# อธิบาย:
# ตัวอักษรที่ไม่ซ้ำ เช่น h, e, w, r, d, (และตัวอื่นที่ไม่ซ้ำ) รวมทั้งหมด 7 ตัว

# %%
# string = input()
# print(len(set(string.lower().replace(" ",""))))
# Out:
# Hello World
# 7

# %% [markdown]
# ให้เขียนโปรแกรมรับข้อความ 1 บรรทัด แล้วหาว่า
# คำ (word) ไหนปรากฏบ่อยที่สุด และปรากฏกี่ครั้ง
#
# 🔹 ตัวอย่าง
# Input: cat dog cat bird dog cat
# Output: cat 3

# %%
# string = input().lower()

# mydict = {}
# splited = string.split(" ")

# for i in splited:
#   mydict[i] = mydict.setdefault(i, 0) + 1

# key = max(mydict, key=mydict.get)
# max_value = max(mydict.values())

# print(f"{key} {max_value}")
# Out:
# cat 3

# %% [markdown]
# เขียนโปรแกรมภาษา Python ที่:
#
# รับค่าจำนวนเต็ม n จากผู้ใช้
# หาผลรวมของ “เลขคู่ทั้งหมด” ตั้งแต่ 1 ถึง n
# แสดงผลลัพธ์ออกมา
# 🔍 ตัวอย่าง
#
# Input:
#
# n = 10
#
# Output:
#
# ผลรวมเลขคู่ = 30
#
# ถ้า n น้อยกว่า 1 ให้แสดงข้อความว่า "Invalid input"

# %%
# n = int(input("n ="))


# if n < 1:
#   print("Invalid input")
# else:
#   sum_even = 0
#   for i in range(1, n+1):
#     if i % 2 == 0:
#       sum_even += i

#   print(f"ผลรวมเลขคู่ = {sum_even}")

# """
# n = int(input("n = "))

# if n < 1:
#     print("Invalid input")
# else:
#     k = n // 2
#     sum_even = k * (k + 1)
#     print(f"ผลรวมเลขคู่ = {sum_even}")

# """
# Out:
# n =10
# ผลรวมเลขคู่ = 30
