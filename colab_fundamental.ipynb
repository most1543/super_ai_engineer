# %% [markdown]
# <a href="https://colab.research.google.com/github/most1543/super_ai_engineer/blob/main/colab_fundamental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1) Create Section

# %% [markdown]
# Section

# %% [markdown]
# ### 2) Text Cell

# %% [markdown]
# **สวัสดี**
# *ตัวเอียง*

# %% [markdown]
# ### 3) Code Cell

# %%
x = 2 + 3

# %%
print(x)
# Out:
# 5

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### 4) Import Library

# %%
import numpy
import matplotlib.pyplot as plt

# %%
x =  numpy.array([1,2,3,4,5])
y = 2*x

# %%
print(x)
print(y)
# Out:
# [1 2 3 4 5]
# [ 2  4  6  8 10]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### 5) Install Library

# %%
import pythainlp

# %%
# !pip install pythainlp

# %% [markdown]
# ###6) Session Storage

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# sample_data/

# %%
df = pd.read_csv('cities.csv')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# /tmp/ipykernel_26313/1635081875.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('cities.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %%
ls
# Out:
# cities.csv  sample_data/

# %% [markdown]
# ###7) Form

# %%
# @title Form
text = "Hello" # @param {"type":"string"}
slide = 0 # @param {"type":"slider","min":0,"max":100,"step":1}

# %% [markdown]
# ###8) Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %% [markdown]
# ###9) Github Version Control

# %%
pwd
# Out:
# '/content/drive/MyDrive'

# %%
cd Colab\ Github/
# Out:
# /content/drive/MyDrive/Colab Github

# %%
# !git clone https://github.com/most1543/super_ai_engineer.git
# Out:
# Cloning into 'super_ai_engineer'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
cd super_ai_engineer/
# Out:
# /content/drive/MyDrive/Colab Github/super_ai_engineer

# %%
ls
# Out:
# colab_fundamental.ipynb  README.md

# %%
# !git add .
# !git config --global user.email "most1543@gmail.com"
# !git config --global user.name "Pathawee Klunkuwat"
# !git commit -m "test git colab"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push -u origin master
# Out:
# error: src refspec master does not match any
# error: failed to push some refs to 'https://github.com/most1543/super_ai_engineer.git'
